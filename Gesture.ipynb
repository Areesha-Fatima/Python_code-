# %%
gesture=['smile','tired','thirsty','increase_heart_beat']

def make_agents(gesture):
  return [gesture]
agent_one_a=make_agents(gesture[1])
import random

def generate_random_gest(N):
 new_gest_random=[]
 for i in range(N):
    g1=random.choice(gesture)
    select_random_gesture=make_agents(g1)
    new_gest_random.append(select_random_gesture)
 return new_gest_random

random_gest_ans=generate_random_gest(1) 
print(random_gest_ans)

if random_gest_ans==[['thirsty']]:
  print("your agent is walking")

elif random_gest_ans==[['increase_heart_beat']]:
  print("your agent is running")

elif random_gest_ans==[['smile']]:
  print("your agent is sitting")

elif random_gest_ans==[['tired']]:
  print("your agent is standing")
# Out:
# [['increase_heart_beat']]
# your agent is running
